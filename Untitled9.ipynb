# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaskarnainwal/Python-/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# addition
2+1

3

# subtraction
2-5

-3

# multiplication
2*2

4

# division
3/2

1.5

# floor division
7//3

2

# exponentiation
2**5

32




# modulus
15%6

3

# order of operations followed in python
2+ 10 * 10 +3

105

2 + 10 * (10+3)

132

# scientific notations
4E3

4000.0

# variable
x=5
x

5

y=6.4
y

6.4

print(y)

6.4

# addition
z= x+y
print(z)

11.4

# subtraction
z= x-y
print(z)

-1.4000000000000004

# find out the data type of variable z
type (y)

float

# multiplication
z= x*y
print(z)
type(z)

32.0
float

# division
z= x/y
print(z)
type(z)

0.78125
float

# floor division
z= x//y # remember x=5 , y=6,4
print(z)

0.0

# bool
2==3

False

2==0

False

2!=0

True

2!=0

True

a=3
b=2
a>b

True

b>4

False

a==3

True

10< 45

True

4<2

False

3>=2

True

4>=4

True

3<-0

False

1<=2


True
# Out:
# 6.4
# 11.4
# -1.4000000000000004
# 32.0
# 0.78125
# 0.0
# True
